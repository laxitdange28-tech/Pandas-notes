# %% [markdown]
# <a href="https://colab.research.google.com/github/laxitdange28-tech/Pandas-notes/blob/main/Pandas_2_%26_3_Assign_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Final Assignment (Class 2 + Class 3)
#
# ### Topics Covered
# - head()
# - tail()
# - info()
# - shape
# - dtypes
# - loc
# - iloc
# - rename()
# - set_index()
# - reset_index()
# - isnull()
# - fillna()
# - astype()
# - replace()
# - drop()
# - duplicated()
# - drop_duplicates()
#
# ### Instructions
# - Use Pandas in every question.
# - Write code in the blank code cell below each question.
# - Print the required output.

# %% [markdown]
# # Q1. Display First Rows
#
# ## Problem Statement
# Create the following DataFrame:
#
# | Name | Age |
# |------|-----|
# | Aman | 21 |
# | Rahul | 22 |
# | Neha | 20 |
# | Priya | 23 |
# | Ravi | 24 |
#
# Display the first 3 rows using `head()`.
#
# ## Sample Output
# ```python
# First 3 rows of DataFrame
# ```

# %%
import numpy as np
import pandas as pd

# %%
# Write your code here
df = pd.DataFrame({
    'Name' : ['Aman','Rahul','Neha','Priya','Ravi'],
    'Age' : [21,22,20,23,24]
})


print(df.head(3))
# Out:
#     Name  Age
# 0   Aman   21
# 1  Rahul   22
# 2   Neha   20

# %% [markdown]
# # Q2. Display Last Rows
#
# ## Problem Statement
# Create a DataFrame containing 6 student records.
#
# Display the last 2 rows using `tail()`.
#
# ## Sample Output
# ```python
# Last 2 rows of DataFrame
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'Name' : ['Aman','Rahul','Neha','Priya','Ravi','Rohit'],
    'Age' : [21,22,20,23,24,25]
})


print(df.tail(2))
# Out:
#     Name  Age
# 4   Ravi   24
# 5  Rohit   25

# %% [markdown]
# # Q3. Check DataFrame Information
#
# ## Problem Statement
# Create a DataFrame containing:
#
# ```python
# Name = ["Aman","Rahul","Neha"]
# Marks = [80,75,90]
# ```
#
# Display DataFrame information using `info()`.
#
# ## Sample Output
# ```python
# <class 'pandas.core.frame.DataFrame'>
# ...
# ```

# %%
# Write your code here

df  = pd.DataFrame({
    'Name':['Aman','Rahul','Neha'],
    'Marks':[80,75,90]

})
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes
# None

# %% [markdown]
# # Q4. Shape and Data Types
#
# ## Problem Statement
# Create a DataFrame with:
#
# ```python
# Name
# Age
# City
# ```
#
# Print:
# - Shape
# - Data Types
#
# ## Sample Output
# ```python
# (3,3)
# object
# int64
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'Name' : ['Aman','Rahul', 'Neha'],
    'Age' : [20,22,25],
    'City' : ['Bhopal','Indoer',"Betul"],
})

print(df.shape)
print(df.dtypes)
# Out:
# (3, 3)
# Name    object
# Age      int64
# City    object
# dtype: object

# %% [markdown]
# # Q5. Select Data using loc
#
# ## Problem Statement
# Create a DataFrame with Name, Age and City.
#
# Using `loc`, display the Name and City of the first row.
#
# ## Sample Output
# ```python
# Name    Aman
# City    Bhopal
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'Name' : ['Aman','Rahul','Yash'],
    'Age' : [20,25,19],
    'City' : ['Bhopal','Ujjain','Betul']
})

print(df.loc[0,['Name','City']])
# Out:
# Name      Aman
# City    Bhopal
# Name: 0, dtype: object

# %% [markdown]
# # Q6. Select Data using iloc
#
# ## Problem Statement
# Create a DataFrame with at least 4 rows.
#
# Using `iloc`, print:
# - Second row
# - First two columns
#
# ## Sample Output
# ```python
# Selected row values
# ```

# %%
# Write your code here

df = pd.DataFrame({
    'Name' : ['Yash','Neha','Rahul','Ramesh'],
    'Age'  : [70,20,26,16],
    'City' : ['Bhopal','Indore','Betul','Nagpur']
})
print(df.iloc[1])
print(df.iloc[0:2,0:2])
# Out:
# Name     Neha
# Age        20
# City    Indor
# Name: 1, dtype: object
#    Name  Age
# 0  Yash   70
# 1  Neha   20

# %% [markdown]
# # Q7. Rename a Column
#
# ## Problem Statement
# Create a DataFrame:
#
# ```python
# Name
# Marks
# ```
#
# Rename column `Marks` to `Score`.
#
# ## Sample Output
# ```python
# Name  Score
# ```

# %%
# Write your code here

df = pd.DataFrame({
    'Name' : ['Yash','Neha','Rahul','Ramesh'],
    'Marks'  : [70,20,26,16],
    'City' : ['Bhopal','Indore','Betul','Nagpur']
})

re_name = df.rename(columns={'Marks' : 'Score'})
print(f"{df} \n")
print(re_name)
# Out:
#      Name  Marks    City
# 0    Yash     70  Bhopal
# 1    Neha     20   Indor
# 2   Rahul     26   Betul
# 3  Ramesh     16  Nagpur
#
#      Name  Score    City
# 0    Yash     70  Bhopal
# 1    Neha     20   Indor
# 2   Rahul     26   Betul
# 3  Ramesh     16  Nagpur

# %% [markdown]
# # Q8. Handle Missing Values
#
# ## Problem Statement
# Create a DataFrame:
#
# ```python
# Name = ["Aman", None, "Neha"]
# Marks = [80, 75, None]
# ```
#
# Fill missing values using `fillna()`.
#
# ## Sample Output
# ```python
# Missing values replaced
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'Name' : ['Aman',None,'Neha'],
    'Marks' : [80,75,None]
})

df.fillna(0)
# Out:
#    Name  Marks
# 0  Aman   80.0
# 1     0   75.0
# 2  Neha    0.0

# %% [markdown]
# # Q9. Replace Values
#
# ## Problem Statement
# Create a DataFrame:
#
# ```python
# City = ["BPL", "IND", "BPL"]
# ```
#
# Replace:
# - BPL → Bhopal
# - IND → Indore
#
# ## Sample Output
# ```python
# Bhopal
# Indore
# Bhopal
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'City' : ['BPL','IND','BPL']
})

# Method 1
df.replace(['BPL','IND'],['Bhopal','Indore'])

#Method 2
df.replace({'BPL':'Bhopal','IND':'Indore'})
# Out:
#      City
# 0  Bhopal
# 1  Indore
# 2  Bhopal

# %% [markdown]
# # Q10. Remove Duplicate Records
#
# ## Problem Statement
# Create a DataFrame:
#
# ```python
# Name = ["Aman","Rahul","Aman","Neha"]
# ```
#
# Check duplicate rows using `duplicated()` and remove them using `drop_duplicates()`.
#
# ## Sample Output
# ```python
# Aman
# Rahul
# Neha
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'Name' : ['Aman','Rahul','Aman','Neha']
})

# check duplicat
df.duplicated()

# remove duplicate
df.drop_duplicates(inplace=True)
print(df)
# Out:
#     Name
# 0   Aman
# 1  Rahul
# 3   Neha
