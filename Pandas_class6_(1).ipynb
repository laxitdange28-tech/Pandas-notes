# %% [markdown]
# <a href="https://colab.research.google.com/github/laxitdange28-tech/Pandas-notes/blob/main/Pandas_class6_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 6: GroupBy & Aggregations
# Welcome to **Class 6** of our Pandas series. Today we’ll learn how to group data and perform aggregations.

# %% [markdown]
# ## 1. Concept of Split–Apply–Combine
# - **Split** the data into groups based on some criteria.
# - **Apply** a function (e.g., sum, mean) to each group.
# - **Combine** the results into a new DataFrame or Series.
#
# This is the core idea behind `groupby`.

# %%
import pandas as pd

# New dataset: Employees, their Department, and Salary
data = {
    "Employee": ["John", "Sarah", "Mike", "Anna", "Tom", "Laura", "Steve", "Kate"],
    "Department": ["HR", "IT", "IT", "Finance", "Finance", "HR", "IT", "Finance"],
    "Salary": [50000, 70000, 72000, 65000, 60000, 52000, 75000, 58000]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#   Employee Department  Salary
# 0     John         HR   50000
# 1    Sarah         IT   70000
# 2     Mike         IT   72000
# 3     Anna    Finance   65000
# 4      Tom    Finance   60000
# 5    Laura         HR   52000
# 6    Steve         IT   75000
# 7     Kate    Finance   58000

# %%
avg_salary   = df.groupby('Department')['Salary'].mean() #Har department ki average salary kyab hai?

count_people = df.groupby('Department')['Employee'].count() #Har department mai kitne log hai?

multi_stats  = df.groupby('Department')['Salary'].agg(['mean','min','max'])
print(multi_stats)
# Out:
#                     mean    min    max
# Department
# Finance     61000.000000  58000  65000
# HR          51000.000000  50000  52000
# IT          72333.333333  70000  75000

# %% [markdown]
# ## 2. Using `groupby()` with Aggregation Functions
# - Use `groupby('col').mean()` or other functions like sum, count, min, max.
# - You can also use `agg()` to pass multiple functions at once.

# %%
multi_stats  = df.groupby('Department')['Salary'].agg(['mean','min','max'])

# %% [markdown]
# ## 3. Multiple Aggregations on Different Columns
# - With `agg()`, you can specify different functions for each column.
# - Example: `df.groupby('Dept').agg({'Salary':'mean', 'Age':'max'})`.

# %%
import pandas as pd

# Same dataset
data = {
    "Employee": ["John", "Sarah", "Mike", "Anna", "Tom", "Laura", "Steve", "Kate"],
    "Department": ["HR", "IT", "IT", "Finance", "Finance", "HR", "IT", "Finance"],
    "Salary": [50000, 70000, 72000, 65000, 60000, 52000, 75000, 58000],
    "Age": [28, 32, 30, 27, 35, 29, 31, 26]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)

#Department wise average Age.
df.groupby('Department')['Age'].mean()

# df.groupby('Department').agg({column:ispe lagana kya hai mean, min,max,count?})
print(df.groupby('Department').agg(
    {'Salary':['mean','min','max'],
     'Age': ['min','max']}
))
# Out:
# Original DataFrame:
#   Employee Department  Salary  Age
# 0     John         HR   50000   28
# 1    Sarah         IT   70000   32
# 2     Mike         IT   72000   30
# 3     Anna    Finance   65000   27
# 4      Tom    Finance   60000   35
# 5    Laura         HR   52000   29
# 6    Steve         IT   75000   31
# 7     Kate    Finance   58000   26
#                   Salary               Age
#                     mean    min    max min max
# Department
# Finance     61000.000000  58000  65000  26  35
# HR          51000.000000  50000  52000  28  29
# IT          72333.333333  70000  75000  30  32

# %% [markdown]
# ## 4. Pivot Tables & Crosstab
# - `pivot_table()` summarizes data like Excel pivot tables.
# - `crosstab()` shows frequency counts of combinations of factors.
# - Both are powerful for summarizing and comparing groups.

# %%
# df.pivot_table(index='konsa column main hai', values="Kya chahiye", aggfunc=mean,min,max,coiunt)
df.pivot_table(index='Department', values='Salary', aggfunc='mean')

df.pivot_table(index='Department', values=['Salary','Age'], aggfunc='mean')


#Age Group -> 25-30, 31-35
df['Age_Group'] = pd.cut(df['Age'], bins=[25,30,35,40], labels=["25-30", "31-35", "36-40"])
pd.crosstab(df['Department'], df['Age_Group'])
# Out:
#                   Age        Salary
# Department
# Finance     29.333333  61000.000000
# HR          28.500000  51000.000000
# IT          31.000000  72333.333333

# %% [markdown]
# ## Mini Practice
# 1. Create a DataFrame with columns: Department, Employee, Salary, Age, City.
# 2. Group by Department to get average Salary and max Age.
# 3. Apply multiple aggregations using agg().
# 4. Create a pivot_table to see mean Salary by Department and City.
# 5. Build a crosstab for Department vs City.

# %%
# 1. Create a DataFrame with columns: Department, Employee, Salary, Age, City

# 2. Group by Department to get average Salary and max Age
# Write your code here

# 3. Apply multiple aggregations using agg()
# Example: mean Salary, max Age per Department
# Write your code here

# 4. Create a pivot_table to see mean Salary by Department and City
# Write your code here

# 5. Build a crosstab for Department vs City
# Write your code here

# %%
# 1. Create a DataFrame with columns: Department, Employee, Salary, Age, City
import pandas as pd

data = {
    "Department": ["HR", "IT", "IT", "Finance", "Finance", "HR", "IT", "Finance"],
    "Employee": ["John", "Sarah", "Mike", "Anna", "Tom", "Laura", "Steve", "Kate"],
  "Salary": [50000, 70000, 72000, 65000, 60000, 52000, 75000, 5800],
    "Age": [28, 32, 30, 27, 35, 29, 31, 26],
    "City": ["New York", "San Francisco", "San Francisco", "Los Angeles", "Los Angeles", "New York", "San Francisco", "Los Angeles"]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#   Department Employee  Salary  Age           City
# 0         HR     John   50000   28       New York
# 1         IT    Sarah   70000   32  San Francisco
# 2         IT     Mike   72000   30  San Francisco
# 3    Finance     Anna   65000   27    Los Angeles
# 4    Finance      Tom   60000   35    Los Angeles
# 5         HR    Laura   52000   29       New York
# 6         IT    Steve   75000   31  San Francisco
# 7    Finance     Kate    5800   26    Los Angeles

# %%
# 2. Group by Department to get average Salary and max Age
# Write your code here
df.groupby('Department').agg({'Salary' : 'mean','Age' : 'max'})
# Out:
#                   Salary  Age
# Department
# Finance     43600.000000   35
# HR          51000.000000   29
# IT          72333.333333   32

# %%
# 3. Apply multiple aggregations using agg()
# Example: mean Salary, max Age per Department
# Write your code here

df.groupby('Department').agg({'Salary' : 'mean' , 'Age':'max'})
# Out:
#                   Salary  Age
# Department
# Finance     43600.000000   35
# HR          51000.000000   29
# IT          72333.333333   32

# %%
# 4. Create a pivot_table to see mean Salary by Department and City
# Write your code here
df.pivot_table(index='Department', columns='City', values='Salary', aggfunc='mean')
# Out:
# City        Los Angeles  New York  San Francisco
# Department
# Finance         43600.0       NaN            NaN
# HR                  NaN   51000.0            NaN
# IT                  NaN       NaN   72333.333333

# %%
# 5. Build a crosstab for Department vs City
# Write your code here
pd.crosstab(df['Department'], df['City'])
# Out:
# City        Los Angeles  New York  San Francisco
# Department
# Finance               3         0              0
# HR                    0         2              0
# IT                    0         0              3

# %% [markdown]
# ---
# ## Summary
# - Learned the split–apply–combine concept.
# - Used `groupby()` with aggregation functions.
# - Applied multiple aggregations to different columns.
# - Explored `pivot_table` and `crosstab` for summarizing data.
